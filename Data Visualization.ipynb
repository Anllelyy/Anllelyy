# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Data visualization: Visualize all predictor variables and analyze its distributions using
# appropriate visualization methods. Analyze the distribution of the response variable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import shapiro

# %%
df = pd.read_excel('CleanData.xlsx')
df.head(5)
# Out:
#    General_Health  Checkup  Exercise  Heart_Disease  Skin_Cancer  \
# 0               4        2         0              1            0
# 1               4        2         1              0            0
# 2               1        2         1              1            0
# 3               3        2         0              0            0
# 4               2        2         1              1            0
#
#    Other_Cancer  Depression  Arthritis  Age_Category  Height_(cm)  ...  \
# 0             0           0          0            11        165.0  ...
# 1             0           0          0             9        163.0  ...
# 2             0           0          0            12        180.0  ...
# 3             0           0          0            13        191.0  ...
# 4             0           0          1             9        175.0  ...
#
#    Fruit_Consumption  Green_Vegetables_Consumption  FriedPotato_Consumption  \
# ...

# %% [markdown]
# ### Response Variable Heart_Disease

# %%
# Dataframe
Heart_Disease = df['Heart_Disease'].value_counts()

# Data for the pie chart
labels = Heart_Disease.index
sizes = Heart_Disease.values
colors=[ 'crimson', 'orange', 'crimson','gold', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink']

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=4)

# Legend labels
legend_labels = ['0 - No Heart Disease', '1 - Yes, have Heart Disease']  # Replace with actual names
plt.legend(legend_labels, title='Category', bbox_to_anchor=(1, 0.5), loc='center left')

# Add title
plt.title('Distribution of Heart_Disease')

# Show the plot
plt.show()

# %%
# Create the histogram
Heart_Disease = df['Heart_Disease'].value_counts()

# Create a bar chart
ax = Heart_Disease.plot(kind='bar', color=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise'])

# Add labels and title
plt.xlabel('Heart_Disease')
plt.ylabel('Frequency')
plt.title('Distribution Heart_Disease')

# Add legend with corrected labels
plt.legend(['0 - Heart_Disease', '1 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['Heart_Disease'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Heart_Disease):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ### General_Health

# %%
datos = df['General_Health']
# Crear el histograma
# contar el número de casos para cada categoría de Skin_Carnce
General_Health_cases = df['General_Health'].value_counts()

# crear un gráfico de barras
ax = General_Health_cases.plot(kind='bar')

# cambiar el color de la barra cada barra
ax.patches[0].set_facecolor('red')
ax.patches[1].set_facecolor('orange')
ax.patches[2].set_facecolor('gold')
ax.patches[3].set_facecolor('limegreen')
ax.patches[4].set_facecolor('darkturquoise')



# agregar etiquetas y título
plt.xlabel('General Health')
plt.ylabel('Frecuencia')
plt.title('Bar Chart General Health')

# agregar leyenda
plt.legend(['4 - Very Good', '3 - Good', '5 - Excellent', '2 - Fair','1 - Poor'], title='Category')

#Calculate percentage
for i, value in enumerate(General_Health_cases):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')



# mostrar el gráfico
plt.show()

# %%
# Dataframe
General_Health = df['General_Health'].value_counts()

# Data for the pie chart
labels = General_Health.index
sizes = General_Health.values
colors=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink']

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=4)

# Legend labels
legend_labels = ['4 - Very Good', '3 - Good', '5 - Excellent', '2 - Fair','1 - Poor']  # Replace with actual names
plt.legend(legend_labels, title='Category', bbox_to_anchor=(1, 0.5), loc='center left')

# Add title
plt.title('Distribution of General_Health')

# Show the plot
plt.show()

# %% [markdown]
# ### Checkup

# %%
# Crear el histograma
# contar el número de casos para cada categoría de Skin_Carnce
Checkup = df['Checkup'].value_counts()

# crear un gráfico de barras
ax = Checkup.plot(kind='bar')

# cambiar el color de la barra cada barra
ax.patches[0].set_facecolor('crimson')
ax.patches[1].set_facecolor('orange')
ax.patches[2].set_facecolor('gold')
ax.patches[3].set_facecolor('limegreen')
ax.patches[4].set_facecolor('darkturquoise')



# agregar etiquetas y título
plt.xlabel(' Checkup')
plt.ylabel('Frecuency')
plt.title('Bar Chart Checkup')

# agregar leyenda
plt.legend(['2 - Within the past year', '3 - Within the past 2 years', '4 - Within the past 5 years', '5 - 5 or more years ago','1 - Never'], title='Category')

#Calculate percentage
for i, value in enumerate(Checkup):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# mostrar el gráfico
plt.show()

# %%
# Dataframe
General_Health = df['Checkup'].value_counts()

# Data for the pie chart
labels = General_Health.index
sizes = General_Health.values
colors=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink']

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=4)

# Legend labels
legend_labels = ['2 - Within the past year', '3 - Within the past 2 years', '4 - Within the past 5 years', '5 - 5 or more years ago','1 - Never']  # Replace with actual names
plt.legend(legend_labels, title='Category', bbox_to_anchor=(1, 0.5), loc='center left')

# Add title
plt.title('Distribution of General_Health')

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise

# %%
# Create the histogram
Exercise = df['Exercise'].value_counts()

# Create a bar chart
ax = Exercise.plot(kind='bar', color=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise'])

# Add labels and title
plt.xlabel('Exercise')
plt.ylabel('Frequency')
plt.title('Bar Chart Exercise')

# Add legend with corrected labels
plt.legend(['1 - Yes', '0 - No'], title='Category')

# Calculate total number of cases
total_cases = len(df['Exercise'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Exercise):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ### Skin Cancer

# %%
# Contar el número de casos para cada categoría de Skin_Cancer
Skinc_Cancer_cases = df['Skin_Cancer'].value_counts()

# Crear un gráfico de barras
ax = Skinc_Cancer_cases.plot(kind='bar', color=['crimson', 'orange'])

#Calculate percentage
for i, value in enumerate(Skinc_Cancer_cases):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')


# Agregar etiquetas y título
plt.xlabel('Skin_Cancer')
plt.ylabel('Frecuencia')
plt.title('Bar Chart Skin_Cancer')

# Agregar leyenda manualmente
plt.legend(['No Skin Cancer', 'Sí Cancer'], title='Category')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Other_Cancer

# %%
# Create the histogram
Other_Cancer = df['Other_Cancer'].value_counts()

# Create a bar chart
ax = Other_Cancer.plot(kind='bar', color=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise'])

# Add labels and title
plt.xlabel('Other Cancer')
plt.ylabel('Frequency')
plt.title('Bar Chart Other Cancer')

# Add legend with corrected labels
plt.legend(['0 - No Other Cancer', '1 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['Other_Cancer'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Other_Cancer):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ### Depression

# %%
# Create the histogram
Depression = df['Depression'].value_counts()

# Create a bar chart
ax = Depression.plot(kind='bar', color=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise'])

# Add labels and title
plt.xlabel('Depression')
plt.ylabel('Frequency')
plt.title('Bar Chart Depression')

# Add legend with corrected labels
plt.legend(['0 - No Depression', '0 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['Depression'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Depression):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ### Arthritis

# %%
# Create the histogram
Arthritis = df['Arthritis'].value_counts()

# Create a bar chart
ax = Arthritis.plot(kind='bar', color=['crimson', 'orange', 'gold', 'limegreen', 'darkturquoise'])

# Add labels and title
plt.xlabel('Arthritis')
plt.ylabel('Frequency')
plt.title('Distribution Arthritis')

# Add legend with corrected labels
plt.legend(['0 - No Arthritis', '1 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['Arthritis'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Arthritis):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# ### Sex

# %% [markdown]
# ### Age_Category

# %%
# Create the histogram
Age_Category = df['Age_Category'].value_counts()

# Create a bar chart
ax = Age_Category.plot(kind='bar', color=['crimson','orangered', 'orange', 'gold','greenyellow', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink'], width=0.6)

# Add labels and title
plt.xlabel('Age_Category')
plt.ylabel('Frequency')
plt.title('Distributiont Age_Category')


# Calculate total number of cases
total_cases = len(df['Age_Category'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Age_Category):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=6)

# Show the plot
plt.show()

# %%
# Dataframe
Age_Category = df['Age_Category'].value_counts()

# Data for the pie chart
labels = Age_Category.index
sizes = Age_Category.values
colors=['crimson','orangered', 'orange', 'gold','greenyellow', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink']

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=4)

# Legend labels
legend_labels = ['10: [65-69] years', '9: [60-64] years', '11: [70-74] years', '8: [55-59] years','7: [50-54] years', '13: [80+] years','12: [75-79] years','5: [40-44] years','6: [45-49] years','4: [35-39] years','1: [18-24] years','3: [30-34] years','2: [25-29] years']  # Replace with actual names
plt.legend(legend_labels, title='Category', bbox_to_anchor=(1, 0.5), loc='center left')

# Add title
plt.title('Distribution of General_Health')

# Show the plot
plt.show()

# %% [markdown]
# ### BMI

# %%
# Create the histogram
BMI = df['BMI'].value_counts()

# Create a bar chart
ax = BMI.plot(kind='bar', color=['crimson', 'orange', 'greenyellow', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink'], width=0.6)

# Add labels and title
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('Distribution BMI')

# Add legend with corrected labels
plt.legend(['3 - dmkd', '0 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['BMI'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(BMI):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=6)

# Show the plot
plt.show()

# %%
def Classify_BMI(BMI):
    if BMI >= 0.0 and BMI < 18.5:
        return 1 #"Underweight"
    elif BMI >= 18.5 and BMI < 25.0:
        return 2 #"Normal Weight"
    elif BMI >= 25.0 and BMI < 30.0:
        return 3#"Overweight"
    elif BMI >= 30.0 and BMI < 35.0:
        return 4#"Obesity Class 1"
    elif BMI >= 35.0 and BMI < 40.0:
        return 5#"Obesity Class 2"
    elif BMI >= 40.0:
        return 6#"Obesity Class 3"

# %%
# Dataframe
BMI = df['BMI'].value_counts()

# Data for the pie chart
labels = BMI.index
sizes = BMI.values
colors=['crimson', 'orange','greenyellow', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink']

# Create the pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=4)

# Legend labels
legend_labels = ['3 - Overweight', '2 - Normal Weight', '4 - Obesity Class 1', '5 - Obesity Class 2',"1 - Underweight","",""]  # Replace with actual names
plt.legend(legend_labels, title='Category', bbox_to_anchor=(1, 0.5), loc='center left')

# Add title
plt.title('Distribution of BMI')

# Show the plot
plt.show()

# %% [markdown]
# ### Smoking_History

# %%
# Create the histogram
Smoking_History = df['Smoking_History'].value_counts()

# Create a bar chart
ax = Smoking_History.plot(kind='bar', color=['crimson', 'orange', 'greenyellow', 'limegreen', 'darkturquoise', 'deepskyblue','mediumblue','rebeccapurple','darkorchid','deeppink','hotpink'], width=0.6)

# Add labels and title
plt.xlabel('Smoking_History')
plt.ylabel('Frequency')
plt.title('Distribution Smoking_History')

# Add legend with corrected labels
plt.legend(['0 - No', '1 - Yes'], title='Category')

# Calculate total number of cases
total_cases = len(df['Smoking_History'])

# Calculate and display the percentage on top of each bar
for i, value in enumerate(Smoking_History):
    percentage = (value / total_cases) * 100
    ax.text(i, value + 1, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=10)

# Show the plot
plt.show()

# %% [markdown]
# ### Continuas (Numéricas)

# %% [markdown]
# ### Height_(cm)

# %%
# Create density plot
sns.displot(df, x='Height_(cm)', kind='kde', color='deeppink')

# Add title and labels
plt.title('Distribution of Height')
plt.xlabel('Height')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
# Data
data = df['Height_(cm)']

# Create el histograma
plt.hist(data,  color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('Height')
plt.ylabel('Frecuency')
plt.title('Histogram Distribution Height (cm)')

# Mostrar el histograma
plt.show()

# %%
# Realizar la prueba de Shapiro-Wilk
stat, p_value = shapiro(data)

# Imprimir los resultados
print(f'Estadístico de prueba: {stat}')
print(f'Valor p: {p_value}')

# Comparar el valor p con un umbral de significancia común (por ejemplo, 0.05)
alpha = 0.05
if p_value > alpha:
    print('No se rechaza la hipótesis nula. Los datos pueden seguir una distribución normal.')
else:
    print('Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.')
# Out:
# Estadístico de prueba: 0.9880989193916321
# Valor p: 0.0
# Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.
# /Users/anllely/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
df['Height_(cm)'].describe()
# Out:
# count    283302.000000
# mean        170.358970
# std          10.211768
# min         142.000000
# 25%         163.000000
# 50%         170.000000
# 75%         178.000000
# max         200.000000
# Name: Height_(cm), dtype: float64

# %% [markdown]
# ### Weight_(kg)

# %%
# Create density plot
sns.displot(df, x='Weight_(kg)', kind='kde', color='deeppink')

# Add title and labels
plt.title('Distribution of Weight')
plt.xlabel('Weight ')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
df['Weight_(kg)'].describe()
# Out:
# count    283302.000000
# mean         79.636136
# std          16.336960
# min          35.380000
# 25%          68.040000
# 50%          79.380000
# 75%          90.720000
# max         120.000000
# Name: Weight_(kg), dtype: float64

# %%
# Data
data_weight = df['Weight_(kg)']

# Create el histograma
plt.hist(data_weight,  color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('Weight (kg)')
plt.ylabel('Frecuency')
plt.title('Distribution of Weight')

# Mostrar el histograma
plt.show()

# %%
# Realizar la prueba de Shapiro-Wilk
stat, p_value = shapiro(data_weight)

# Imprimir los resultados
print(f'Estadístico de prueba: {stat}')
print(f'Valor p: {p_value}')

# Comparar el valor p con un umbral de significancia común (por ejemplo, 0.05)
alpha = 0.05
if p_value > alpha:
    print('No se rechaza la hipótesis nula. Los datos pueden seguir una distribución normal.')
else:
    print('Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.')
# Out:
# Estadístico de prueba: 0.989605188369751
# Valor p: 0.0
# Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.
# /Users/anllely/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# ### Alcohol_Consumption

# %%
# Create density plot
sns.displot(df, x='Alcohol_Consumption', kind='kde', color='deeppink')

# Add title and labels
plt.title('Distribution of Alcohol_Consumption')
plt.xlabel('Alcohol_Consumption')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
# Data
Alcohol_Consumption = df['Alcohol_Consumption']

# Create el histograma
plt.hist(Alcohol_Consumption, color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('Alcohol_Consumption')
plt.ylabel('Frecuency')
plt.title('Histogram')

# Mostrar el histograma
plt.show()

# %%
# Realizar la prueba de Shapiro-Wilk
data_a=df['Alcohol_Consumption']
stat, p_value = shapiro(data_a)

# Imprimir los resultados
print(f'Estadístico de prueba: {stat}')
print(f'Valor p: {p_value}')

# Comparar el valor p con un umbral de significancia común (por ejemplo, 0.05)
alpha = 0.05
if p_value > alpha:
    print('No se rechaza la hipótesis nula. Los datos pueden seguir una distribución normal.')
else:
    print('Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.')
# Out:
# Estadístico de prueba: 0.6739886999130249
# Valor p: 0.0
# Se rechaza la hipótesis nula. Los datos no siguen una distribución normal.
# /Users/anllely/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1816: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
from scipy.stats import gamma, kstest
import numpy as np

# Supongamos que 'data' es tu conjunto de datos
data = np.array(df['Alcohol_Consumption'])

# Parámetros estimados de la distribución gamma
alpha, loc, beta = gamma.fit(data)

# Genera datos de la distribución gamma ajustada
gamma_fitted = gamma.rvs(alpha, loc=loc, scale=beta, size=len(data))

# Prueba de Kolmogorov-Smirnov
ks_statistic, ks_p_value = kstest(data, 'gamma', args=(alpha, loc, beta))

print(f"Estadístico de prueba KS: {ks_statistic}")
print(f"P-valor: {ks_p_value}")

# Puedes usar ks_p_value para tomar decisiones sobre la hipótesis nula
# Por ejemplo, si ks_p_value < 0.05, podrías rechazar la hipótesis nula de que los datos siguen una distribución gamma.
# Out:
# Estadístico de prueba KS: 0.446936418360647
# P-valor: 0.0

# %%
from scipy.stats import gamma, kstest

data = df['Alcohol_Consumption']  # You can replace this data with your own

# Perform the Kolmogorov-Smirnov test
ks_statistic, p_value = kstest(data, 'gamma', args=(2,))  # 'gamma' indicates the gamma distribution with parameter 'a=2'

# Print results
print(f'KS test statistic: {ks_statistic}')
print(f'P-value: {p_value}')

# Make a decision based on the p-value (using a significance level of 0.05)
significance_level = 0.05
if p_value > significance_level:
    print('Fail to reject the null hypothesis. The data follows a gamma distribution.')
else:
    print('Reject the null hypothesis. The data does not follow a gamma distribution.')

# Visualize the data and the fitted gamma distribution for illustrative purposes
plt.hist(data, bins=30, density=True, alpha=0.5, color='blue', label='Observed data')
x = np.linspace(0, max(data), 100)
plt.plot(x, gamma.pdf(x, a=2), 'r-', lw=2, label='Fitted gamma distribution (a=2)')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Goodness of Fit Test to Gamma Distribution')
plt.legend()
plt.show()
# Out:
# KS test statistic: 0.44693648474066544
# P-value: 0.0
# Reject the null hypothesis. The data does not follow a gamma distribution.

# %% [markdown]
# ### Fruit_Consumption

# %%
# Create density plot
sns.displot(df, x='Fruit_Consumption', kind='kde', color='deeppink')

# Add title and labels
plt.title('Distribution of Fruit Consumption')
plt.xlabel('Fruit_Consumption')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
df['Fruit_Consumption'].describe()
# Out:
# count    283302.000000
# mean         30.163952
# std          24.950803
# min           0.000000
# 25%          12.000000
# 50%          30.000000
# 75%          30.000000
# max         120.000000
# Name: Fruit_Consumption, dtype: float64

# %%
# Data
Fruit_Consumption = df['Fruit_Consumption']

# Create el histograma
plt.hist(Fruit_Consumption, color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('Fruit_Consumption')
plt.ylabel('Frecuency')
plt.title('Histogram')

# Mostrar el histograma
plt.show()

# %% [markdown]
# ### Green_Vegetables_Consumption

# %%
df['Green_Vegetables_Consumption'].describe()
# Out:
# count    283302.000000
# mean         15.318152
# std          15.016647
# min           0.000000
# 25%           4.000000
# 50%          12.000000
# 75%          20.000000
# max         128.000000
# Name: Green_Vegetables_Consumption, dtype: float64

# %%
# Create density plot
sns.displot(df, x='Green_Vegetables_Consumption', kind='kde', color='deeppink')

# Add title and labels
plt.title('Distribution of Green_Vegetables_Consumption')
plt.xlabel('Green_Vegetables_Consumption')
plt.ylabel('Density')

# Show the plot
plt.show()

# %%
# Data
Green_Vegetables_Consumption = df['Green_Vegetables_Consumption']

# Create el histograma
plt.hist(Green_Vegetables_Consumption, color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('Green_Vegetables_Consumption')
plt.ylabel('Frecuency')
plt.title('Distribution of Green_Vegetables_Consumption')

# Mostrar el histograma
plt.show()

# %%
data = df['Green_Vegetables_Consumption'] 

# Perform the Kolmogorov-Smirnov test
ks_statistic, p_value = kstest(data, 'gamma', args=(2,))  # 'gamma' indicates the gamma distribution with parameter 'a=2'

# Print results
print(f'KS test statistic: {ks_statistic}')
print(f'P-value: {p_value}')

# Make a decision based on the p-value (using a significance level of 0.05)
significance_level = 0.05
if p_value > significance_level:
    print('Fail to reject the null hypothesis. The data follows a gamma distribution.')
else:
    print('Reject the null hypothesis. The data does not follow a gamma distribution.')

# Visualize the data and the fitted gamma distribution for illustrative purposes
plt.hist(data, bins=30, density=True, alpha=0.5, color='blue', label='Observed data')
x = np.linspace(0, max(data), 100)
plt.plot(x, gamma.pdf(x, a=2), 'r-', lw=2, label='Fitted gamma distribution (a=2)')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Goodness of Fit Test to Gamma Distribution')
plt.legend()
plt.show()
# Out:
# KS test statistic: 0.7577522020942992
# P-value: 0.0
# Reject the null hypothesis. The data does not follow a gamma distribution.

# %% [markdown]
# ### FriedPotato Consumption

# %%
# Data
FriedPotato_Consumption = df['FriedPotato_Consumption']

# Create el histograma
plt.hist(FriedPotato_Consumption, color='deeppink', edgecolor='black')

# Agregar etiquetas y título
plt.xlabel('FriedPotato_Consumption')
plt.ylabel('Frecuency')
plt.title('Distribution of FriedPotato_Consumption')

# Mostrar el histograma
plt.show()

# %%
df['FriedPotato_Consumption'].describe()
# Out:
# count    283302.000000
# mean          6.186543
# std           8.509859
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           8.000000
# max         128.000000
# Name: FriedPotato_Consumption, dtype: float64

# %%
data = df['FriedPotato_Consumption'] 

# Perform the Kolmogorov-Smirnov test
ks_statistic, p_value = kstest(data, 'gamma', args=(2,))  # 'gamma' indicates the gamma distribution with parameter 'a=2'

# Print results
print(f'KS test statistic: {ks_statistic}')
print(f'P-value: {p_value}')

# Make a decision based on the p-value (using a significance level of 0.05)
significance_level = 0.05
if p_value > significance_level:
    print('Fail to reject the null hypothesis. The data follows a gamma distribution.')
else:
    print('Reject the null hypothesis. The data does not follow a gamma distribution.')

# Visualize the data and the fitted gamma distribution for illustrative purposes
plt.hist(data, bins=30, density=True, alpha=0.5, color='blue', label='Observed data')
x = np.linspace(0, max(data), 100)
plt.plot(x, gamma.pdf(x, a=2), 'r-', lw=2, label='Fitted gamma distribution (a=2)')
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Goodness of Fit Test to Gamma Distribution')
plt.legend()
plt.show()
# Out:
# KS test statistic: 0.4948207720302686
# P-value: 0.0
# Reject the null hypothesis. The data does not follow a gamma distribution.

# %%
df.columns
# Out:
# Index(['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer',
#        'Other_Cancer', 'Depression', 'Arthritis', 'Age_Category',
#        'Height_(cm)', 'Weight_(kg)', 'BMI', 'Smoking_History',
#        'Alcohol_Consumption', 'Fruit_Consumption',
#        'Green_Vegetables_Consumption', 'FriedPotato_Consumption',
#        'Diabetes_No', 'Diabetes_No, pre-diabetes or borderline diabetes',
#        'Diabetes_Yes', 'Diabetes_Yes, but female told only during pregnancy',
#        'Sex_Female', 'Sex_Male', 'Sex_Non-Binary'],
#       dtype='object')

# %%
df.head()
# Out:
#    General_Health  Checkup  Exercise  Heart_Disease  Skin_Cancer  \
# 0               4        2         0              1            0
# 1               4        2         1              0            0
# 2               1        2         1              1            0
# 3               3        2         0              0            0
# 4               2        2         1              1            0
#
#    Other_Cancer  Depression  Arthritis  Age_Category  Height_(cm)  ...  \
# 0             0           0          0            11        165.0  ...
# 1             0           0          0             9        163.0  ...
# 2             0           0          0            12        180.0  ...
# 3             0           0          0            13        191.0  ...
# 4             0           0          1             9        175.0  ...
#
#    Fruit_Consumption  Green_Vegetables_Consumption  FriedPotato_Consumption  \
# ...
